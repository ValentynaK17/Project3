# %% [markdown]
# # Project 4 - Books Recommendation using SVD
# Collaborative based filtering->Item based

# %%
# !pip install scikit-surprise

# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from surprise import accuracy, Dataset, Reader, SVD, BaselineOnly, PredictionImpossible
from surprise.model_selection import train_test_split, cross_validate, KFold, GridSearchCV
import random
import numpy as np
import statistics as st

# %% [markdown]
# # Explore the data

# %%
#Creating dataframes from csv files to read the data
books_df_original = pd.read_csv('./Resources/BooksO.csv')
users_df = pd.read_csv('./Resources/UsersO.csv')
ratings_df_original = pd.read_csv('./Resources/RatingsO.csv')
# Out:
# /var/folders/3g/t4y_09d901v7s2qw9dqk8jzw0000gn/T/ipykernel_49057/2406171956.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df_original = pd.read_csv('./Resources/BooksO.csv')
# /var/folders/3g/t4y_09d901v7s2qw9dqk8jzw0000gn/T/ipykernel_49057/2406171956.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   users_df = pd.read_csv('./Resources/UsersO.csv')
# /var/folders/3g/t4y_09d901v7s2qw9dqk8jzw0000gn/T/ipykernel_49057/2406171956.py:4: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   ratings_df_original = pd.read_csv('./Resources/RatingsO.csv')

# %%
# Filter out data with no publication year
books_df = books_df_original[books_df_original['Year-Of-Publication'] != 0]

# %%
# remove duplicated books records if any by looking at ISBN
books_df=books_df.drop_duplicates(subset=['ISBN'])

# %%
books_df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 267790 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 267790 non-null  object
#  1   Book-Title           267790 non-null  object
#  2   Book-Author          267788 non-null  object
#  3   Year-Of-Publication  267790 non-null  object
#  4   Publisher            267788 non-null  object
#  5   Image-URL-S          267790 non-null  object
#  6   Image-URL-M          267790 non-null  object
#  7   Image-URL-L          267787 non-null  object
# dtypes: object(8)
# memory usage: 18.4+ MB

# %%
duplicated_titles=books_df[books_df.duplicated(subset=['Book-Title'],keep=False)].sort_values(by='Book-Title')
duplicated_titles.head()
# ????????how to handle those duplicates????????
# Out:
#               ISBN                                         Book-Title  \
# 75637   1565920465                          !%@ (A Nutshell handbook)
# 156341  1565920317                          !%@ (A Nutshell handbook)
# 140618  0792276833  'A Hell of a Place to Lose a Cow': An American...
# 158204  0792277295  'A Hell of a Place to Lose a Cow': An American...
# 10438   0451168089                                       'Salem's Lot
#
#           Book-Author Year-Of-Publication            Publisher  \
# 75637   Donnalyn Frey                1994             O'Reilly
# 156341  Donnalyn Frey                1993             O'Reilly
# 140618    Tim Brookes                2000  National Geographic
# 158204    Tim Brookes                2001  National Geographic
# 10438    Stephen King                1990          Signet Book
#
#                                               Image-URL-S  \
# 75637   http://images.amazon.com/images/P/1565920465.0...
# 156341  http://images.amazon.com/images/P/1565920317.0...
# 140618  http://images.amazon.com/images/P/0792276833.0...
# 158204  http://images.amazon.com/images/P/0792277295.0...
# 10438   http://images.amazon.com/images/P/0451168089.0...
#
#                                               Image-URL-M  \
# 75637   http://images.amazon.com/images/P/1565920465.0...
# 156341  http://images.amazon.com/images/P/1565920317.0...
# 140618  http://images.amazon.com/images/P/0792276833.0...
# 158204  http://images.amazon.com/images/P/0792277295.0...
# 10438   http://images.amazon.com/images/P/0451168089.0...
#
#                                               Image-URL-L
# 75637   http://images.amazon.com/images/P/1565920465.0...
# 156341  http://images.amazon.com/images/P/1565920317.0...
# 140618  http://images.amazon.com/images/P/0792276833.0...
# 158204  http://images.amazon.com/images/P/0792277295.0...
# 10438   http://images.amazon.com/images/P/0451168089.0...

# %%
# create a dictionary for mapping between Book-Title ans ISBN
isbn_title_dict=dict(books_df.set_index('ISBN')['Book-Title'])

# %%
ratings_df=ratings_df_original.copy()
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433684 entries, 0 to 433683
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   User-ID      433684 non-null  object
#  1   ISBN         433682 non-null  object
#  2   Book-Rating  433682 non-null  object
# dtypes: object(3)
# memory usage: 9.9+ MB

# %%
# update the datatype of a 'Book-Rating' field to numeric one
ratings_df['Book-Rating']=pd.to_numeric(ratings_df['Book-Rating'],errors='coerce')
# and check the result
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433684 entries, 0 to 433683
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   User-ID      433684 non-null  object
#  1   ISBN         433682 non-null  object
#  2   Book-Rating  433681 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 9.9+ MB

# %%
############## users with solid number of reviews shortens a lot!
# find the list of ISBN that we have book info for them
isbn=books_df['ISBN'].unique()

# adjust ratings  dataframe to match with those books
ratings_df=ratings_df[ratings_df['ISBN'].isin(isbn)]
############## users with solid number of reviews shortens a lot!

# %%
#check for n/a values
ratings_df[ratings_df['Book-Rating'].isna()|ratings_df['ISBN'].isna()|ratings_df['User-ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [User-ID, ISBN, Book-Rating]
# Index: []

# %%
# drop rows with N/As if any
ratings_df=ratings_df[~(ratings_df['Book-Rating'].isna()|ratings_df['ISBN'].isna()|ratings_df['User-ID'].isna())]
ratings_df
# Out:
#        User-ID        ISBN  Book-Rating
# 1       276729  052165615X          3.0
# 5       276744  038550120X          7.0
# 11      276747  1885408226          7.0
# 13      276751  3596218098          8.0
# 18      276762  3453092007          8.0
# ...        ...         ...          ...
# 433639  276688  038073107X          6.0
# 433642  276688  044661193X          7.0
# 433661  276688  1551669315          6.0
# 433662  276688  1575660792          7.0
# 433667  276704  1563526298          9.0
#
# [78518 rows x 3 columns]

# %%
# Check distribution by scores 
groupped_r_scores=ratings_df.groupby(['Book-Rating']).size()
groupped_r_scores
# Out:
# Book-Rating
# 1.0       380
# 2.0       581
# 3.0      1216
# 4.0      1770
# 5.0      8884
# 6.0      6766
# 7.0     13770
# 8.0     18513
# 9.0     11850
# 10.0    14788
# dtype: int64

# %%
groupped_r_scores.plot.bar()
# Out:
# <Axes: xlabel='Book-Rating'>

# %%
# check distribution by number of rated books per user
groupped_r_users=ratings_df.groupby('User-ID')['Book-Rating'].count()
groupped_r_users=pd.DataFrame(groupped_r_users).reset_index()
groupped_r_users
# Out:
#       User-ID  Book-Rating
# 0           8            5
# 1          12            1
# 2          22            1
# 3          64            1
# 4          69            1
# ...       ...          ...
# 26234  276670            8
# 26235  276680           11
# 26236  276681            2
# 26237  276688            5
# 26238  276704            1
#
# [26239 rows x 2 columns]

# %%
users_count_r=groupped_r_users['Book-Rating'].value_counts()
users_count_r=pd.DataFrame(users_count_r).reset_index()
users_count_r.columns = ['Book-Ratings count', 'users count']
users_count_r.sort_values(by='Book-Ratings count')
# Out:
#      Book-Ratings count  users count
# 0                     1        16938
# 1                     2         3587
# 2                     3         1618
# 3                     4          990
# 4                     5          590
# ..                  ...          ...
# 89                  240            1
# 70                  289            1
# 79                  343            1
# 104                1047            1
# 100                1755            1
#
# [106 rows x 2 columns]

# %%
# split df[col_name] into bins
### TO REDO bining part, using approach learned during classes!!!!!!!!!!!!!!!!!
def binning(bins_start, df, col_name, bin_col_name):  
    # bins_start is a list with start points of ranges for binning, e.g. bins_start=[0,25,50,100,300]
    # df - dataframe with data to bin
    # col_name - name of a column in df to bin
    # name of newly created column for labels with bin identificator
    bins_labels=[]
    for i in range(0,len(bins_start)):
        if i<(len(bins_start)-1):
            label=f'({bins_start[i]}-{bins_start[i+1]}]'
        else:
            label=f'>{bins_start[i]}'
        bins_labels.append(label)
    df[bin_col_name]=''
    for index,row in df.iterrows():
        for i in range(0,len(bins_start)):
            if i<(len(bins_start)-1):
                if ((row[col_name]>bins_start[i]) and (row[col_name]<=bins_start[i+1])):
                    df.loc[index,bin_col_name]=bins_labels[i]
            else:
                if row[col_name]>bins_start[i]:
                    df.loc[index,bin_col_name]=bins_labels[i]
    # df[df[bin_col_name]=='']
    return df

# %%
# split book-ratings count per user into bins to visualize and undertand the distribution
users_count_r=binning([0,5,10,25,50,100,300], users_count_r, 'Book-Ratings count', 'Rated Books in Range')
users_count_r
# Out:
#      Book-Ratings count  users count Rated Books in Range
# 0                     1        16938                (0-5]
# 1                     2         3587                (0-5]
# 2                     3         1618                (0-5]
# 3                     4          990                (0-5]
# 4                     5          590                (0-5]
# ..                  ...          ...                  ...
# 101                 143            1            (100-300]
# 102                  78            1             (50-100]
# 103                 122            1            (100-300]
# 104                1047            1                 >300
# 105                  72            1             (50-100]
#
# [106 rows x 3 columns]

# %%
users_count_binned=users_count_r.groupby('Rated Books in Range')['users count'].sum().sort_values(ascending=False)
users_count_binned
# Out:
# Rated Books in Range
# (0-5]        23723
# (5-10]        1297
# (10-25]        888
# (25-50]        241
# (50-100]        64
# (100-300]       23
# >300             3
# Name: users count, dtype: int64

# %%
ax=users_count_binned.plot.bar(color='purple')
ax.set_title("User count distributed by count of rating made")
ax.set_xlabel("range of books number rated by individual")
ax.set_ylabel("how many users made rates within the range")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=7)
plt.tight_layout()

# %%
# check distribution by number of users, who gave rates for a book
groupped_r_books=ratings_df.groupby('ISBN')['User-ID'].count().sort_values()
groupped_r_books=pd.DataFrame(groupped_r_books).reset_index().rename(columns={'User-ID':'count_of_users_rated'})
groupped_r_books
# Out:
#              ISBN  count_of_users_rated
# 0      000104687X                     1
# 1      1894593073                     1
# 2      1894549090                     1
# 3      1894498178                     1
# 4      1894463196                     1
# ...           ...                   ...
# 40292  043935806X                   206
# 40293  044021145X                   208
# 40294  067976402X                   256
# 40295  044023722X                   281
# 40296  059035342X                   313
#
# [40297 rows x 2 columns]

# %%
# split book-ratings count per book into bins to visualize and undertand the distribution
groupped_r_books=binning([0,5,10,25,50,100,300], groupped_r_books, 'count_of_users_rated', 'users_count_range')
groupped_r_books
# Out:
#              ISBN  count_of_users_rated users_count_range
# 0      000104687X                     1             (0-5]
# 1      1894593073                     1             (0-5]
# 2      1894549090                     1             (0-5]
# 3      1894498178                     1             (0-5]
# 4      1894463196                     1             (0-5]
# ...           ...                   ...               ...
# 40292  043935806X                   206         (100-300]
# 40293  044021145X                   208         (100-300]
# 40294  067976402X                   256         (100-300]
# 40295  044023722X                   281         (100-300]
# 40296  059035342X                   313              >300
#
# [40297 rows x 3 columns]

# %%
books_count_binned=groupped_r_books.groupby('users_count_range')['ISBN'].count().sort_values(ascending=False)
books_count_binned
# Out:
# users_count_range
# (0-5]        38588
# (5-10]        1051
# (10-25]        498
# (25-50]         94
# (50-100]        53
# (100-300]       12
# >300             1
# Name: ISBN, dtype: int64

# %%
ax=books_count_binned.plot.bar()
ax.set_title('Books distributed by popularity')
ax.set_xlabel("range of users reviewed a book")
ax.set_ylabel("books number within popularity range")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=7)
plt.tight_layout()

# %%
# to find the most liked books (positively popular) we can consider approach like this one
ratings_df[ratings_df['Book-Rating']>=8].groupby('ISBN').count().sort_values('Book-Rating',ascending=False)[:10]
# Out:
#             User-ID  Book-Rating
# ISBN
# 059035342X      276          276
# 043935806X      176          176
# 067976402X      173          173
# 044023722X      155          155
# 044021145X      135          135
# 1400034779      126          126
# 1558743669       91           91
# 068484477X       91           91
# 044651652X       89           89
# 014028009X       79           79

# %% [markdown]
# # Train the model

# %% [markdown]
# # Training: data preparation

# %% [markdown]
# ### Change ISBN with Titles
# Merge ratings with books data in order to change isbn with title and leave only those ratings data for which we have title info

# %%
ratings_df
# Out:
#        User-ID        ISBN  Book-Rating
# 1       276729  052165615X          3.0
# 5       276744  038550120X          7.0
# 11      276747  1885408226          7.0
# 13      276751  3596218098          8.0
# 18      276762  3453092007          8.0
# ...        ...         ...          ...
# 433639  276688  038073107X          6.0
# 433642  276688  044661193X          7.0
# 433661  276688  1551669315          6.0
# 433662  276688  1575660792          7.0
# 433667  276704  1563526298          9.0
#
# [78518 rows x 3 columns]

# %%
ratings_df=pd.merge(books_df,ratings_df,on='ISBN', how = 'inner')
ratings_df
# Out:
#              ISBN                                         Book-Title  \
# 0      074322678X            Where You'll Find Me: And Other Stories
# 1      1552041778                                           Jane Doe
# 2      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 3      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# ...           ...                                                ...
# 78513  3453065123  Ich war Hitlerjunge Salomon. ( erlebt und erfa...
# 78514  3525335423                Das Deutsche Kaiserreich 1871-1918.
# 78515  3548740146       Wicca. Eine EinfÃ?Â¼hrung in weiÃ?Â?e Magie.
# 78516  381440176X  Ein Fall fÃ?Â¼r TKKG, Bd.50, Sklaven fÃ?Â¼r Wu...
# 78517  1845170423                                  Cocktail Classics
#
#               Book-Author Year-Of-Publication                   Publisher  \
# 0             Ann Beattie                2002                    Scribner
# 1            R. J. Kaiser                1999                  Mira Books
# 2           Jack Canfield                1998       Health Communications
# 3           Jack Canfield                1998       Health Communications
# 4           Jack Canfield                1998       Health Communications
# ...                   ...                 ...                         ...
# 78513         Sally Perel                1993                       Heyne
# 78514  Hans-Ulrich Wehler                1994  Vandenhoeck &amp; Ruprecht
# 78515    Scott Cunningham                2001        Ullstein TB-Vlg., B.
# 78516         Stefan Wolf                1989                     Pelikan
# 78517         David Biggs                2004                   Connaught
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/074322678X.0...
# 1      http://images.amazon.com/images/P/1552041778.0...
# 2      http://images.amazon.com/images/P/1558746218.0...
# 3      http://images.amazon.com/images/P/1558746218.0...
# 4      http://images.amazon.com/images/P/1558746218.0...
# ...                                                  ...
# 78513  http://images.amazon.com/images/P/3453065123.0...
# 78514  http://images.amazon.com/images/P/3525335423.0...
# 78515  http://images.amazon.com/images/P/3548740146.0...
# 78516  http://images.amazon.com/images/P/381440176X.0...
# 78517  http://images.amazon.com/images/P/1845170423.0...
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/074322678X.0...
# 1      http://images.amazon.com/images/P/1552041778.0...
# 2      http://images.amazon.com/images/P/1558746218.0...
# 3      http://images.amazon.com/images/P/1558746218.0...
# 4      http://images.amazon.com/images/P/1558746218.0...
# ...                                                  ...
# 78513  http://images.amazon.com/images/P/3453065123.0...
# 78514  http://images.amazon.com/images/P/3525335423.0...
# 78515  http://images.amazon.com/images/P/3548740146.0...
# 78516  http://images.amazon.com/images/P/381440176X.0...
# 78517  http://images.amazon.com/images/P/1845170423.0...
#
#                                              Image-URL-L User-ID  Book-Rating
# 0      http://images.amazon.com/images/P/074322678X.0...       8          5.0
# 1      http://images.amazon.com/images/P/1552041778.0...       8          5.0
# 2      http://images.amazon.com/images/P/1558746218.0...   61501          7.0
# 3      http://images.amazon.com/images/P/1558746218.0...  148514         10.0
# 4      http://images.amazon.com/images/P/1558746218.0...  263256         10.0
# ...                                                  ...     ...          ...
# 78513  http://images.amazon.com/images/P/3453065123.0...  274220          9.0
# 78514  http://images.amazon.com/images/P/3525335423.0...  274220          8.0
# 78515  http://images.amazon.com/images/P/3548740146.0...  274220          6.0
# 78516  http://images.amazon.com/images/P/381440176X.0...  274220          8.0
# 78517  http://images.amazon.com/images/P/1845170423.0...  275970          7.0
#
# [78518 rows x 10 columns]

# %%
ratings_df=ratings_df.drop(['ISBN','Book-Author','Year-Of-Publication','Publisher','Image-URL-S','Image-URL-M','Image-URL-L'], axis=1)
ratings_df
# Out:
#                                               Book-Title User-ID  Book-Rating
# 0                Where You'll Find Me: And Other Stories       8          5.0
# 1                                               Jane Doe       8          5.0
# 2      A Second Chicken Soup for the Woman's Soul (Ch...   61501          7.0
# 3      A Second Chicken Soup for the Woman's Soul (Ch...  148514         10.0
# 4      A Second Chicken Soup for the Woman's Soul (Ch...  263256         10.0
# ...                                                  ...     ...          ...
# 78513  Ich war Hitlerjunge Salomon. ( erlebt und erfa...  274220          9.0
# 78514                Das Deutsche Kaiserreich 1871-1918.  274220          8.0
# 78515       Wicca. Eine EinfÃ?Â¼hrung in weiÃ?Â?e Magie.  274220          6.0
# 78516  Ein Fall fÃ?Â¼r TKKG, Bd.50, Sklaven fÃ?Â¼r Wu...  274220          8.0
# 78517                                  Cocktail Classics  275970          7.0
#
# [78518 rows x 3 columns]

# %%
ratings_df=ratings_df.dropna()
ratings_df
# Out:
#                                               Book-Title User-ID  Book-Rating
# 0                Where You'll Find Me: And Other Stories       8          5.0
# 1                                               Jane Doe       8          5.0
# 2      A Second Chicken Soup for the Woman's Soul (Ch...   61501          7.0
# 3      A Second Chicken Soup for the Woman's Soul (Ch...  148514         10.0
# 4      A Second Chicken Soup for the Woman's Soul (Ch...  263256         10.0
# ...                                                  ...     ...          ...
# 78513  Ich war Hitlerjunge Salomon. ( erlebt und erfa...  274220          9.0
# 78514                Das Deutsche Kaiserreich 1871-1918.  274220          8.0
# 78515       Wicca. Eine EinfÃ?Â¼hrung in weiÃ?Â?e Magie.  274220          6.0
# 78516  Ein Fall fÃ?Â¼r TKKG, Bd.50, Sklaven fÃ?Â¼r Wu...  274220          8.0
# 78517                                  Cocktail Classics  275970          7.0
#
# [78518 rows x 3 columns]

# %%
# check if there are duplicated records when same user rated book(s) with same title several times
ratings_df[ratings_df.duplicated(subset=['Book-Title', 'User-ID'],keep=False)].sort_values(by=['Book-Title','User-ID'])
# Out:
#                                               Book-Title User-ID  Book-Rating
# 29815                        A Language Older Than Words   11676         10.0
# 44715                        A Language Older Than Words   11676          8.0
# 29816                        A Language Older Than Words   72428         10.0
# 44717                        A Language Older Than Words   72428         10.0
# 649                                      A Painted House   11676          8.0
# ...                                                  ...     ...          ...
# 53617                                  Widowhood Happens   87582         10.0
# 53645  Zoids Chaotic Century (Zoids: Chaotic Century ...   63714         10.0
# 53646  Zoids Chaotic Century (Zoids: Chaotic Century ...   63714         10.0
# 53647  Zoids Chaotic Century (Zoids: Chaotic Century ...   63714         10.0
# 53648  Zoids Chaotic Century (Zoids: Chaotic Century ...   63714         10.0
#
# [165 rows x 3 columns]

# %%
# drop duplicated records when same user could rate book(s) with same title
ratings_df=ratings_df.drop_duplicates()
ratings_df
# Out:
#                                               Book-Title User-ID  Book-Rating
# 0                Where You'll Find Me: And Other Stories       8          5.0
# 1                                               Jane Doe       8          5.0
# 2      A Second Chicken Soup for the Woman's Soul (Ch...   61501          7.0
# 3      A Second Chicken Soup for the Woman's Soul (Ch...  148514         10.0
# 4      A Second Chicken Soup for the Woman's Soul (Ch...  263256         10.0
# ...                                                  ...     ...          ...
# 78513  Ich war Hitlerjunge Salomon. ( erlebt und erfa...  274220          9.0
# 78514                Das Deutsche Kaiserreich 1871-1918.  274220          8.0
# 78515       Wicca. Eine EinfÃ?Â¼hrung in weiÃ?Â?e Magie.  274220          6.0
# 78516  Ein Fall fÃ?Â¼r TKKG, Bd.50, Sklaven fÃ?Â¼r Wu...  274220          8.0
# 78517                                  Cocktail Classics  275970          7.0
#
# [78450 rows x 3 columns]

# %%
#??????????
# should we may have avg rate here per duplicates set????
#??????????

# %% [markdown]
# ### Only leave statistically signifacant data

# %%
# Define whar are the number of rates per book and books rated by user we treat as statistically significant
min_books_rated_by_user=5
min_rates_received_by_book=5

# %%
groupped_r_users=ratings_df.groupby('User-ID')['Book-Rating'].count()
groupped_r_users[:5]
# Out:
# User-ID
# 8     5
# 12    1
# 22    1
# 64    1
# 69    1
# Name: Book-Rating, dtype: int64

# %%
groupped_r_books=ratings_df.groupby('Book-Title')['User-ID'].count()
groupped_r_books[:5]
# Out:
# Book-Title
#  Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth    7
#  Final Fantasy Anthology: Official Strategy Guide (Brady Games)                                     2
#  Flight of Fancy: American Heiresses (Zebra Ballad Romance)                                         1
#  Little Comic Shop of Horrors (Give Yourself Goosebumps, Book 17)                                   1
#  Q-Zone (Star Trek The Next Generation, Book 48)                                                    2
# Name: User-ID, dtype: int64

# %%
#select only those books which were rated more than min_rates_received_by_book
titles_with_acceptable_rates_count=list(groupped_r_books[groupped_r_books>min_rates_received_by_book].index)
titles_with_acceptable_rates_count[:5]
# Out:
# [' Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth',
#  '10,000 dreams interpreted: A dictionary of dreams',
#  '101 Best Home-Based Businesses for Women',
#  '16 Lighthouse Road',
#  '1984 (Spanish Language Edition)']

# %%
#select only those users (user_id) who rated more than min_books_rated_by_user books
user_ids_with_acceptable_books_count_rated=list(groupped_r_users[groupped_r_users>min_books_rated_by_user].index)
user_ids_with_acceptable_books_count_rated[:5]
# Out:
# [242, 254, 392, 625, 643]

# %%
# filter rating-user data to have only books/users of interest (which have highest rates count and rated highest number of books respectively)
rating_input_df=ratings_df[ratings_df['Book-Title'].isin(titles_with_acceptable_rates_count)&ratings_df['User-ID'].isin(user_ids_with_acceptable_books_count_rated)]
rating_input_df
# Out:
#                                               Book-Title User-ID  Book-Rating
# 9      New Vegetarian: Bold and Beautiful Recipes for...    6366          7.0
# 10     New Vegetarian: Bold and Beautiful Recipes for...   11676         10.0
# 11     New Vegetarian: Bold and Beautiful Recipes for...  131126         10.0
# 14     New Vegetarian: Bold and Beautiful Recipes for...  156502         10.0
# 15     New Vegetarian: Bold and Beautiful Recipes for...  157118          8.0
# ...                                                  ...     ...          ...
# 76649                                       Hin und weg.  155035          8.0
# 77215                          Ausweitung der Kampfzone.  176047          3.0
# 77610                                            Montana  216012          8.0
# 78015                            The Great Train Robbery  234828          7.0
# 78390                          The Voyage of the Narwhal  243942          7.0
#
# [11911 rows x 3 columns]

# %% [markdown]
# ### Prepare data for parsing by 'surprise algorithms'

# %%
# Even having dataframe we need to create a 'reader' with the 'rating_scale' parameter to let know that our dataset has ratings from 1 to 10
# https://surprise.readthedocs.io/en/stable/getting_started.html#load-custom
reader = Reader(rating_scale=(1,10))

# and create respective surprise.dataset object, so that our data are in a proper format for the recommendation algorithms
data_surprise_o = Dataset.load_from_df(rating_input_df[['User-ID','Book-Title','Book-Rating']], reader)

data_surprise_o

# %% [markdown]
# #### Split our data into train and test in ratio 8:2
# Use random_state = 42 so that we receive reproducable output

# %%
random_state = 42

# %%
# Option1:
# Reference: https://surprise.readthedocs.io/en/stable/getting_started.html?highlight=train_test_split#train-test-split-and-the-fit-method

train_set, test_set = train_test_split(data_surprise_o, test_size=0.2, shuffle=True, random_state=random_state)

train_data = list(train_set.all_ratings())

print(f'Size of train_set: {len(train_data)}')
print(f'Number of users in train_set: {train_set.n_users}')
print(f'Number of books in train_set: {train_set.n_items}')

train_set
# Out:
# Size of train_set: 9528
# Number of users in train_set: 2164
# Number of books in train_set: 1754

# %%
train_set.all_items()
# Out:
# range(0, 1754)

# %%
# Option2:
# reference: https://datascience.stackexchange.com/questions/73583/how-to-train-test-split-and-cross-validate-in-surprise
# get already parsed data in its raw form
# check here for raw vs inner https://surprise.readthedocs.io/en/stable/FAQ.html#what-are-raw-and-inner-ids
train_dataset_obj = Dataset.load_from_df(rating_input_df[['User-ID','Book-Title','Book-Rating']], reader) # we kind of copying the original dataset
raw_data = train_dataset_obj.raw_ratings

# shuffle ratings to ensure that the data is randomized
np.random.seed(random_state)
np.random.shuffle(raw_data)
display (f'Size of raw_data: {len(raw_data)}')
display(f'Few elements of raw_data: {raw_data[:5]}')

#???????????????
# WHY DO WE HAVE 'None' here as 4-th element?
#???????????????
# Out:
# 'Size of raw_data: 11911'
# 'Few elements of raw_data: [(\'253852\', \'Le Guide galactique, tome 1\', 10.0, None), (11676, \'Livealbum.\', 6.0, None), (102705, \'One True Thing\', 8.0, None), (\'224904\', \'Chobits (Chobits)\', 6.0, None), (125203, "L\'Ecume Des Jours", 10.0, None)]'

# %%
# find the lenght of train set having it should be 80% of all data
train_lenght = int(0.8 * len(raw_data))
# split the whole set of raw data into train and test one
train_part_raw = raw_data[:train_lenght]
test_part_raw = raw_data[train_lenght:]

# create respective train object and test set
train_dataset_obj.raw_ratings=train_part_raw  #trick to receive a dataset object from raw data 'train_part_raw'
train_set = train_dataset_obj.build_full_trainset()
test_set = train_dataset_obj.construct_testset(test_part_raw)
print(f'Type of train_set: {type(train_set)}')
print(f'Type of test_set: {type(test_set)}')
# Out:
# Type of train_set: <class 'surprise.trainset.Trainset'>
# Type of test_set: <class 'list'>

# %%
# check train and test data
train_data = list(train_set.all_ratings())

display('------Train Set------')
print(f'Size of train_set: {len(train_data)}')
print(f'Number of users in train_set: {train_set.n_users}')
print(f'Number of books in train_set: {train_set.n_items}')
display(f'Few elements of train_set (user, book, rating): {train_data[:15]}')
display('------Test Set------')
print(f'Size of test_set: {len(test_set)}')
display(f'Few elements of test_set (user, book, rating): {test_set[:15]}')
# Out:
# '------Train Set------'
# Size of train_set: 9528
# Number of users in train_set: 2164
# Number of books in train_set: 1754
# 'Few elements of train_set (user, book, rating): [(0, 0, 10.0), (0, 841, 7.0), (0, 413, 9.0), (0, 1122, 9.0), (0, 1014, 10.0), (0, 1298, 7.0), (0, 1078, 9.0), (0, 1380, 8.0), (1, 1, 6.0), (1, 8, 5.0), (1, 14, 9.0), (1, 15, 9.0), (1, 34, 4.0), (1, 38, 7.0), (1, 45, 8.0)]'
# '------Test Set------'
# Size of test_set: 2383
# 'Few elements of test_set (user, book, rating): [(67775, \'West Of Bliss\', 7.0), (\'275970\', \'9-11\', 10.0), (\'206441\', \'Warum MÃ?Â¤nner nicht zuhÃ?Â¶ren und Frauen schlecht einparken.\', 5.0), (\'255489\', "The No. 1 Ladies\' Detective Agency", 6.0), (122793, \'Lake News\', 9.0), (103541, \'Einfach gÃ?Â¶ttlich. Ein Roman von der bizarren Scheibenwelt.\', 10.0), (9908, \'Petals on the River\', 10.0), (52199, "Harry Potter and the Sorcerer\'s Stone (Harry Potter (Paperback))", 7.0), (29915, \'Grace Notes\', 4.0), (28634, \'Deadly Grace\', 9.0), (\'201548\', \'Weit wie das Meer.\', 10.0), (\'271558\', \'Time Bomb (Alex Delaware Novels (Paperback))\', 7.0), (\'165308\', "Bridget Jones\'s Diary", 10.0), (136916, \'The Prayer of Jabez: Breaking Through to the Blessed Life\', 8.0), (10560, \'Blood Canticle (The Vampire Chronicles)\', 5.0)]'

# %%
# not really sure I understand the difference here between options (in general it's stated that the second one works if we want to cross validate)
# can we receive more input here?????

# %% [markdown]
# ## Training: cross validate the model
# Make preliminary estimation of error in predictions using RMSE metric for SVD() model and the whole set of data split into 5 folds

# %%
# reference: https://surprise.readthedocs.io/en/stable/getting_started.html?highlight=cross_validate#use-cross-validation-iterators

# define number of subsets the dataset will be partitioned for cross validations
folds_n=5

# define a cross-validation iterator
kf = KFold(n_splits=folds_n,random_state=42)

algo = [BaselineOnly(),SVD()]

for i in algo:
    mean_rmse=[]
    for trainset, testset in kf.split(data_surprise_o):

        # train and test algorithm.
        i.fit(trainset)
        predictions = i.test(testset)

        # Compute and print Root Mean Squared Error
        mean_rmse.append(accuracy.rmse(predictions))

    # Find an average rmse for all the folds
    mean_rmse=st.mean(mean_rmse)
    display(f'Average Root Mean Square Error (RMSE) for {i.__class__.__name__} is {round(mean_rmse,2)}')
# Out:
# Estimating biases using als...
# RMSE: 1.6711
# Estimating biases using als...
# RMSE: 1.6858
# Estimating biases using als...
# RMSE: 1.6794
# Estimating biases using als...
# RMSE: 1.6499
# Estimating biases using als...
# RMSE: 1.6589
# 'Average Root Mean Square Error (RMSE) for BaselineOnly is 1.67'
# RMSE: 1.6601
# RMSE: 1.6744
# RMSE: 1.6691
# RMSE: 1.6357
# RMSE: 1.6494
# 'Average Root Mean Square Error (RMSE) for SVD is 1.66'

# %% [markdown]
# ## Training: identify best parameters

# %%
# # reference: https://medium.com/p/61c269402919
# # within the dictionary param_grid set ranges for parameters to try out, where 
# #  - key: parameter name, 
# #  - value:  list of parameter values to try
# param_grid = {'n_factors':[10,20,50,100,150], 'n_epochs':[10,20,30,50, 100], 'lr_all':[0.002,0.005,0.01,0.3],'reg_all':[0.02, 0.1, 0.2]}
# # n_factors - number of latent factors (Default is 100)
# # n_epochs - number of iterations (Default is 20)
# # lr_all - step size for the gradient descent optimization (learning rate, Default is 0.005)
# # reg_all -  regularization term for all parameter, used to prevent overfitting (Default is 0.02)

# # Select parameters for our SVD algorithm by cross validation and looking for rmse metric
# # GridSearchCV() calculates a score for each combination of hyperparameters on a k-fold cross validated dataset 
# # and returns the set of parameters that minimises the mean score across folds
# gs = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=5)

# # train the model for all the combinations of parameters
# gs.fit(data_surprise_o)

# # select the set of parameters that produce lowest value for rmse metric
# params = gs.best_params['rmse']

# params
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 17
#      14 gs = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=5)
#      16 # train the model for all the combinations of parameters
# ---> 17 gs.fit(data_surprise_o)
#      19 # select the set of parameters that produce lowest value for rmse metric
#      20 params = gs.best_params['rmse']
#
# File ~/anaconda3/lib/python3.11/site-packages/surprise/model_selection/search.py:104, in BaseSearchCV.fit(self, data)
#      90 cv = get_cv(self.cv)
#      92 delayed_list = (
#      93     delayed(fit_and_score)(
#      94         self.algo_class(**params),
#    (...)
#     102     )
#     103 )
# --> 104 out = Parallel(
#     105     n_jobs=self.n_jobs,
#     106     pre_dispatch=self.pre_dispatch,
#     107     verbose=self.joblib_verbose,
#     108 )(delayed_list)
#     110 (test_measures_dicts, train_measures_dicts, fit_times, test_times) = zip(*out)
#     112 # test_measures_dicts is a list of dict like this:
#     113 # [{'mae': 1, 'rmse': 2}, {'mae': 2, 'rmse': 3} ...]
#     114 # E.g. for 5 splits, the first 5 dicts are for the first param
#    (...)
#     121 # (n_parameters_combinations, n_splits). This way we can easily compute
#     122 # the mean and std dev over all splits or over all param comb.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/surprise/model_selection/validation.py:173, in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     142 """Helper method that trains an algorithm and compute accuracy measures on
#     143 a testset. Also report train and test times.
#     144
#    (...)
#     169         - The testing time in seconds.
#     170 """
#     172 start_fit = time.time()
# --> 173 algo.fit(trainset)
#     174 fit_time = time.time() - start_fit
#     175 start_test = time.time()
#
# File ~/anaconda3/lib/python3.11/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx:155, in surprise.prediction_algorithms.matrix_factorization.SVD.fit()
#
# File ~/anaconda3/lib/python3.11/site-packages/surprise/prediction_algorithms/matrix_factorization.pyx:228, in surprise.prediction_algorithms.matrix_factorization.SVD.sgd()
#
# File ~/anaconda3/lib/python3.11/site-packages/surprise/trainset.py:194, in Trainset.all_ratings(self)
#     192 for u, u_ratings in self.ur.items():
#     193     for i, r in u_ratings:
# --> 194         yield u, i, r
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training: Build models

# %%
# Build SVD with default parameters
svd_default = SVD()

# %%
# Build SVD, using hyperparameters recevied in the result of hypertuning
# svd_best_parameters = SVD(n_factors=params['n_factors'], n_epochs=params['n_epochs'],lr_all=params['lr_all'], reg_all=params['reg_all'])

# %%
# TO DELETE IN CASE WE RUN PARAMETERS TUNING
svd_best_parameters=svd_default
# TO DELETE IN CASE WE RUN PARAMETERS TUNING

# %% [markdown]
# ## Training: Fit models

# %%
# Train the models on trainset
svd_best_parameters_model = svd_best_parameters.fit(train_set)
svd_default_model = svd_default.fit(train_set)

# %% [markdown]
# # Recommendation generation

# %%
# Define the number of books to recommend by algorithm
recommendations_count=5

# %% [markdown]
# ### Find list of books (titles) among which recommendations will be selected

# %%
# let us select dummy user
user_id=148514

# find all the books (titles) in ratings_df. 
# Note, this only include those books which both: 
# (1) were rated at least min_rates_received_by_book times by users, who rated at least min_books_rated_by_user
# and (2) we have titles for those books
# ??????????We may need to remove (1) condition and look for books, which were rated at least once??????????
all_titles=ratings_df['Book-Title'].unique()
all_titles

# find the books (titles) that were rated and presumably read by a user
rated_titles=[i for i in ratings_df.loc[ratings_df['User-ID']==user_id,'Book-Title']]
rated_titles


# find the books (titles) that were not rated and presumably not read by a user
titles_input_to_recommend=[i for i in all_titles if i not in rated_titles]
titles_input_to_recommend[:5]
# Out:
# ["Where You'll Find Me: And Other Stories",
#  'Jane Doe',
#  'The Witchfinder (Amos Walker Mystery Series)',
#  'More Cunning Than Man: A Social History of Rats and Man',
#  'Goodbye to the Buttermilk Sky']

# %%
rated_book_title_rate =[(row['Book-Title'],row['Book-Rating']) for i,row in ratings_df[ratings_df['User-ID']==user_id].iterrows()]
rated_book_title_rate
# Out:
# [("A Second Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series)",
#   10.0),
#  ('A 4th Course of Chicken Soup for the Soul (Chicken Soup for the Soul)',
#   10.0),
#  ('Hugs for Sisters: Stories, Sayings, and Scriptures to Encourage and Inspire (Hugs)',
#   10.0)]

# %% [markdown]
# ### Find predicted ratings for the user for all the books, which were not rated by him/her

# %%
# reference: https://surprise.readthedocs.io/en/stable/algobase.html?highlight=predict
# uid – (Raw) id of the user. 
# iid – (Raw) id of the item.
# verbose (bool) – Whether to print details of the prediction. Default is False.

predictions=[svd_default_model.predict(uid=user_id, iid=i) for i in titles_input_to_recommend]
predictions[:5]
# Out:
# [Prediction(uid=148514, iid="Where You'll Find Me: And Other Stories", r_ui=None, est=7.89284214945424, details={'was_impossible': False}),
#  Prediction(uid=148514, iid='Jane Doe', r_ui=None, est=7.89284214945424, details={'was_impossible': False}),
#  Prediction(uid=148514, iid='The Witchfinder (Amos Walker Mystery Series)', r_ui=None, est=7.89284214945424, details={'was_impossible': False}),
#  Prediction(uid=148514, iid='More Cunning Than Man: A Social History of Rats and Man', r_ui=None, est=7.89284214945424, details={'was_impossible': False}),
#  Prediction(uid=148514, iid='Goodbye to the Buttermilk Sky', r_ui=None, est=7.89284214945424, details={'was_impossible': False})]

# %%
# check of there are any predictions with 'was_impossible': True
predictions_impossible=[i for i in predictions if i.details['was_impossible']==True]
predictions_impossible
# Out:
# []

# %%
# get ratings estimate for books by the user
ratings=[i.est for i in predictions]
ratings[:5]
# Out:
# [7.89284214945424,
#  7.89284214945424,
#  7.89284214945424,
#  7.89284214945424,
#  7.89284214945424]

# %%
# convert predicted estimates by the user for not read books into df
pred_dict={
    'Book_Title':titles_input_to_recommend,
    'Estimated_Rate':ratings}
predictions_book=pd.DataFrame(pred_dict).sort_values('Estimated_Rate',ascending = False)
predictions_book
# Out:
#                                              Book_Title  Estimated_Rate
# 249                            A Tree Grows in Brooklyn        9.005930
# 5164                                  The Secret Garden        8.942672
# 6158  Old Possum's Book of Practical Cats, Illustrat...        8.886607
# 1042  Harry Potter and the Order of the Phoenix (Boo...        8.855987
# 190   Anne of Green Gables (Anne of Green Gables Nov...        8.852440
# ...                                                 ...             ...
# 2296      Petals on the River (Avon Historical Romance)        6.833875
# 5188                                       Killing Time        6.824598
# 4361                            FrÃ?Â¶sche und Prinzen.        6.797389
# 416     Dirty Jokes and Beer : Stories of the Unrefined        6.735911
# 6359                                      House Of God.        6.694725
#
# [39022 rows x 2 columns]

# %%
print(f'for a user {user_id}, who read the following book(s):') #check ratings as well
display(rated_book_title_rate)
print('The recommendation is following:')
display(predictions_book.head(recommendations_count))
# Out:
# for a user 148514, who read the following book(s):
# [("A Second Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series)",
#   10.0),
#  ('A 4th Course of Chicken Soup for the Soul (Chicken Soup for the Soul)',
#   10.0),
#  ('Hugs for Sisters: Stories, Sayings, and Scriptures to Encourage and Inspire (Hugs)',
#   10.0)]
# The recommendation is following:
#                                              Book_Title  Estimated_Rate
# 249                            A Tree Grows in Brooklyn        9.005930
# 5164                                  The Secret Garden        8.942672
# 6158  Old Possum's Book of Practical Cats, Illustrat...        8.886607
# 1042  Harry Potter and the Order of the Phoenix (Boo...        8.855987
# 190   Anne of Green Gables (Anne of Green Gables Nov...        8.852440

# %%
prediction_full_info=pd.merge(predictions_book, books_df, left_on='Book_Title',right_on='Book-Title', how='left')
prediction_full_info=prediction_full_info[['Book_Title','Book-Author','Year-Of-Publication','Publisher', 'Estimated_Rate']]
prediction_full_info.head(20)
# Out:
#                   Book_Title              Book-Author Year-Of-Publication  \
# 0   A Tree Grows in Brooklyn              Betty Smith                1998
# 1   A Tree Grows in Brooklyn              Betty Smith                2001
# 2   A Tree Grows in Brooklyn              Betty Smith                1989
# 3   A Tree Grows in Brooklyn              Betty Smith                1968
# 4          The Secret Garden  Frances Hodgson Burnett                1989
# 5          The Secret Garden       Frances H. Burnett                1997
# 6          The Secret Garden  Frances Hodgson Burnett                1998
# 7          The Secret Garden                M.J. Carr                1993
# 8          The Secret Garden  Frances Hodgson Burnett                1989
# 9          The Secret Garden  Frances Hodgson Burnett                1987
# 10         The Secret Garden       Frances H. Burnett                1987
# 11         The Secret Garden  Frances Hodgson Burnett                1999
# 12         The Secret Garden  Frances Hodgson Burnett                1979
# 13         The Secret Garden  Frances Hodgson Burnett                1991
# 14         The Secret Garden  Frances Hodgson Burnett                1994
# 15         The Secret Garden  Frances Hodgson Burnett                1994
# 16         The Secret Garden  Frances Hodgson Burnett                1998
# 17         The Secret Garden  Frances Hodgson Burnett                1987
# 18         The Secret Garden       Frances H. Burnett                1990
# 19         The Secret Garden  Frances Hodgson Burnett                1993
#
#                                       Publisher  Estimated_Rate
# 0                                     Perennial        9.005930
# 1                                 HarperCollins        9.005930
# 2                   Reader's Digest Association        9.005930
# 3   Turtleback Books Distributed by Demco Media        9.005930
# 4                                     Tor Books        8.942672
# 5                                    Scholastic        8.942672
# 6                                  HarperTrophy        8.942672
# 7                    Scholastic Paperbacks (Mm)        8.942672
# 8                                    Laure Leaf        8.942672
# 9                     David R. Godine Publisher        8.942672
# 10                                       Bantam        8.942672
# 11                                   Scholastic        8.942672
# 12                              Dell Publishing        8.942672
# 13                               Tor Books (Mm)        8.942672
# 14                              Signet Classics        8.942672
# 15                              Signet Classics        8.942672
# 16                                HarperCollins        8.942672
# 17                                  Signet Book        8.942672
# 18                               Yearling Books        8.942672
# 19                             Highbridge Audio        8.942672

# %%
books_df[books_df['Book-Title'].str.contains('Chicken Soup', case=False, na=False)]
# Out:
#               ISBN                                         Book-Title  \
# 14      1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 244     155874262X  Chicken Soup for the Soul (Chicken Soup for th...
# 250     1558744150  Chicken Soup for the Woman's Soul (Chicken Sou...
# 1428    1558744606  Chicken Soup for the Mother's Soul (Chicken So...
# 1894    1558747478  Chicken Soup for the Parent's Soul : 101 Stori...
# ...            ...                                                ...
# 241456  0757300898        Chicken Soup for the Soul Cartoons for Dads
# 247276  1558747281  Chicken Soup for the Golden Soul: Heartwarming...
# 248933  1583755462  A Little Spoonful of Chicken Soup for the Woma...
# 254158  0613362578  Chicken Soup for the Mother's Soul: 101 Storie...
# 256436  1583755454  Chicken Soup for the Kid's Soul (Mini Gift Books)
#
#                Book-Author Year-Of-Publication                Publisher  \
# 14           Jack Canfield                1998    Health Communications
# 244          Jack Canfield                1993    Health Communications
# 250          Jack Canfield                1996    Health Communications
# 1428         Jack Canfield                1997    Health Communications
# 1894    Mark Victor Hansen                2000    Health Communications
# ...                    ...                 ...                      ...
# 241456       Jack Canfield                2003                      HCI
# 247276       Jack Canfield                2000    Health Communications
# 248933       Jack Canfield                1999  Garborg's Heart 'n Home
# 254158       Jack Canfield                2001          Sagebrush Bound
# 256436       Jack Canfield                1999  Garborg's Heart 'n Home
#
#                                               Image-URL-S  \
# 14      http://images.amazon.com/images/P/1558746218.0...
# 244     http://images.amazon.com/images/P/155874262X.0...
# 250     http://images.amazon.com/images/P/1558744150.0...
# 1428    http://images.amazon.com/images/P/1558744606.0...
# 1894    http://images.amazon.com/images/P/1558747478.0...
# ...                                                   ...
# 241456  http://images.amazon.com/images/P/0757300898.0...
# 247276  http://images.amazon.com/images/P/1558747281.0...
# 248933  http://images.amazon.com/images/P/1583755462.0...
# 254158  http://images.amazon.com/images/P/0613362578.0...
# 256436  http://images.amazon.com/images/P/1583755454.0...
#
#                                               Image-URL-M  \
# 14      http://images.amazon.com/images/P/1558746218.0...
# 244     http://images.amazon.com/images/P/155874262X.0...
# 250     http://images.amazon.com/images/P/1558744150.0...
# 1428    http://images.amazon.com/images/P/1558744606.0...
# 1894    http://images.amazon.com/images/P/1558747478.0...
# ...                                                   ...
# 241456  http://images.amazon.com/images/P/0757300898.0...
# 247276  http://images.amazon.com/images/P/1558747281.0...
# 248933  http://images.amazon.com/images/P/1583755462.0...
# 254158  http://images.amazon.com/images/P/0613362578.0...
# 256436  http://images.amazon.com/images/P/1583755454.0...
#
#                                               Image-URL-L
# 14      http://images.amazon.com/images/P/1558746218.0...
# 244     http://images.amazon.com/images/P/155874262X.0...
# 250     http://images.amazon.com/images/P/1558744150.0...
# 1428    http://images.amazon.com/images/P/1558744606.0...
# 1894    http://images.amazon.com/images/P/1558747478.0...
# ...                                                   ...
# 241456  http://images.amazon.com/images/P/0757300898.0...
# 247276  http://images.amazon.com/images/P/1558747281.0...
# 248933  http://images.amazon.com/images/P/1583755462.0...
# 254158  http://images.amazon.com/images/P/0613362578.0...
# 256436  http://images.amazon.com/images/P/1583755454.0...
#
# [123 rows x 8 columns]

# %% [markdown]
# # Check Accuracy

# %%
# Check the accuracy for both default vs tuned method
display(f'Accuracy of a Tuned Model: {accuracy.rmse(svd_best_parameters_model.test(test_set), verbose=False)}')
display(f'Accuracy of a Model with Default Parameters: {accuracy.rmse(svd_default_model.test(test_set), verbose=False)}')
# Out:
# 'Accuracy of a Tuned Model: 1.6469691259075496'
# 'Accuracy of a Model with Default Parameters: 1.6469691259075496'
